# %%
import pandas as pd
import seaborn as sns
import IonPy
from utils_.metrics import load_metrics, clean_up_results
import matplotlib.pyplot as plt

# Set the seaborn styleß
sns.set_style("darkgrid")

# %%
df_results, broken_dirs = load_metrics("/u/vbutoi/victor_space/scratch/dec_results/fixed_vicuna")
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=vicuna7b:scor=loss_score:data=ARO_VGA, no valid .pkl found.
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=flan_t5:scor=generate:data=ARO_VGA, no valid .pkl found.
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=vicuna13b:scor=generate:data=ARO_VGA, no valid .pkl found.
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=vicuna13b:scor=loss_score:data=ARO_VGA, no valid .pkl found.
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=flan_t5:scor=loss_score:data=ARO_VGA, no valid .pkl found.
# Error in /u/vbutoi/victor_space/scratch/dec_results/vicuna_test/exp=vicuna_test:mod=vicuna7b:scor=generate:data=ARO_VGA, no valid .pkl found.

# %%
# Clean up the runs which crashed and thus don't have a pkl file.
clean_up_results(broken_dirs)
# Out:
# Are you sure you want to delete 6 directories? (y/n) n

# %%
df_results.head()
# Out:
#    accuracy class correct_option  id  \
# 0         1   vgr              A   0
# 1         0   vgr              B   1
# 2         1   vgr              B   2
# 3         1   vgr              A   3
# 4         0   vgr              B   4
#
#                                                image  mid_accuracy  \
# 0  /u/vbutoi/victor_space/data/visual_genome/imag...      1.000000
# 1  /u/vbutoi/victor_space/data/visual_genome/imag...      0.500000
# 2  /u/vbutoi/victor_space/data/visual_genome/imag...      0.666667
# 3  /u/vbutoi/victor_space/data/visual_genome/imag...      0.750000
# 4  /u/vbutoi/victor_space/data/visual_genome/imag...      0.600000
#
#                                               prompt result    model backend  \
# 0  Option A: the door is to the left of the shirt...      A  flan_t5      hf
# 1  Option A: the man is to the left of the door. ...      A  flan_t5      hf
# 2  Option A: the shirt is wearing the man. Option...      B  flan_t5      hf
# 3  Option A: the man is on the train car. Option ...      A  flan_t5      hf
# 4  Option A: the door is to the right of the man....      A  flan_t5      hf
#
#   prompt_id benchmark select_by  append_answer caption_dataset pretrained_root
# 0         1   ARO_VGR  generate          False            None            None
# 1         1   ARO_VGR  generate          False            None            None
# 2         1   ARO_VGR  generate          False            None            None
# 3         1   ARO_VGR  generate          False            None            None
# 4         1   ARO_VGR  generate          False            None            None

# %%
df_results = df_results[df_results['benchmark'] == 'ARO_VGR']
df_results = df_results[df_results['model'] == 'vicuna7b']
df_results = df_results[df_results['select_by'] == 'generate']

# %%
df_results
# Out:
#     accuracy class correct_option     id  \
# 0          1   vgr              A      0
# 1          0   vgr              B      1
# 2          1   vgr              A      2
# 3          1   vgr              A      3
# 4          0   vgr              B      4
# ..       ...   ...            ...    ...
# 96         0   vgr              B   9996
# 97         1   vgr              A   9997
# 98         1   vgr              A   9998
# 99         0   vgr              B   9999
# 0          1   vgr              A  10000
#
#                                                 image  mid_accuracy  \
# 0   /u/vbutoi/victor_space/data/visual_genome/imag...      1.000000
# 1   /u/vbutoi/victor_space/data/visual_genome/imag...      0.500000
# 2   /u/vbutoi/victor_space/data/visual_genome/imag...      0.666667
# 3   /u/vbutoi/victor_space/data/visual_genome/imag...      0.750000
# 4   /u/vbutoi/victor_space/data/visual_genome/imag...      0.600000
# ..                                                ...           ...
# 96  /u/vbutoi/victor_space/data/visual_genome/imag...      0.624387
# 97  /u/vbutoi/victor_space/data/visual_genome/imag...      0.624425
# 98  /u/vbutoi/victor_space/data/visual_genome/imag...      0.624462
# 99  /u/vbutoi/victor_space/data/visual_genome/imag...      0.624400
# 0   /u/vbutoi/victor_space/data/visual_genome/imag...      0.624438
#
#                                                prompt result     model  \
# 0   Option A: the door is to the left of the shirt...      A  vicuna7b
# 1   Option A: the man is to the left of the door. ...      A  vicuna7b
# 2   Option A: the man is wearing the shirt. Option...      A  vicuna7b
# 3   Option A: the man is on the train car. Option ...      A  vicuna7b
# 4   Option A: the door is to the right of the man....      A  vicuna7b
# ..                                                ...    ...       ...
# 96  Option A: the hill is to the right of the ship...      A  vicuna7b
# 97  Option A: the ship is to the right of the vill...      A  vicuna7b
# 98  Option A: the ship is to the right of the wate...      A  vicuna7b
# 99  Option A: the ship is to the left of the water...      A  vicuna7b
# 0   Option A: the water is near the village. Optio...      A  vicuna7b
#
#    backend prompt_id benchmark select_by  append_answer caption_dataset  \
# 0       hf         1   ARO_VGR  generate          False            None
# 1       hf         1   ARO_VGR  generate          False            None
# 2       hf         1   ARO_VGR  generate          False            None
# 3       hf         1   ARO_VGR  generate          False            None
# 4       hf         1   ARO_VGR  generate          False            None
# ..     ...       ...       ...       ...            ...             ...
# 96      hf         1   ARO_VGR  generate          False            None
# 97      hf         1   ARO_VGR  generate          False            None
# 98      hf         1   ARO_VGR  generate          False            None
# 99      hf         1   ARO_VGR  generate          False            None
# 0       hf         1   ARO_VGR  generate          False            None
#
#    pretrained_root                                        eval_regime
# 0             None  model:vicuna7b_select_by:generate_benchmark:AR...
# 1             None  model:vicuna7b_select_by:generate_benchmark:AR...
# 2             None  model:vicuna7b_select_by:generate_benchmark:AR...
# 3             None  model:vicuna7b_select_by:generate_benchmark:AR...
# 4             None  model:vicuna7b_select_by:generate_benchmark:AR...
# ..             ...                                                ...
# 96            None  model:vicuna7b_select_by:generate_benchmark:AR...
# 97            None  model:vicuna7b_select_by:generate_benchmark:AR...
# 98            None  model:vicuna7b_select_by:generate_benchmark:AR...
# 99            None  model:vicuna7b_select_by:generate_benchmark:AR...
# 0             None  model:vicuna7b_select_by:generate_benchmark:AR...
#
# [10001 rows x 17 columns]

# %%
# Specify the column names for which you want to find unique values
varying_fields = ["model", "select_by", "benchmark", "class"]

# Find unique values for the specified columns
unique_values = {}
for column in df_results.keys():
    try:
        unique_col_vals = df_results[column].unique()
        if len(unique_col_vals) > 1 and column in varying_fields:
            unique_values[column] = unique_col_vals
            for ucv in unique_col_vals:
                rows = df_results[df_results[column] == ucv]
                print(column, ucv, rows['class'].unique(), len(rows))
    except Exception as e:
        continue

# Print the unique values for each column, if that column has more than one value.
for column, values in unique_values.items():
    print(f"Unique values for {column}: {values}")
# Out:
# select_by loss_score ['vgr'] 10001
# select_by generate ['vgr'] 10001
# Unique values for select_by: ['loss_score' 'generate']

# %%
# Create a new column by concatenating values from 'Column2' and 'Column3'
def combine_columns(row, columns):
    values = [f"{column}:{row[column]}" for column in columns]
    return '_'.join(values)
    
df_results['eval_regime'] = df_results.apply(lambda row: combine_columns(row, varying_fields), axis=1)

# %%
df_results['eval_regime']
# Out:
# 0     model:vicuna7b_select_by:loss_score_benchmark:...
# 1     model:vicuna7b_select_by:loss_score_benchmark:...
# 2     model:vicuna7b_select_by:loss_score_benchmark:...
# 3     model:vicuna7b_select_by:loss_score_benchmark:...
# 4     model:vicuna7b_select_by:loss_score_benchmark:...
#                             ...
# 96    model:vicuna7b_select_by:generate_benchmark:AR...
# 97    model:vicuna7b_select_by:generate_benchmark:AR...
# 98    model:vicuna7b_select_by:generate_benchmark:AR...
# 99    model:vicuna7b_select_by:generate_benchmark:AR...
# 0     model:vicuna7b_select_by:generate_benchmark:AR...
# Name: eval_regime, Length: 20002, dtype: object

# %%
df_results.groupby(['eval_regime'])['accuracy'].mean()
# Out:
# eval_regime
# model:vicuna7b_select_by:generate_benchmark:ARO_VGR_class:vgr      0.624438
# model:vicuna7b_select_by:loss_score_benchmark:ARO_VGR_class:vgr    0.590641
# Name: accuracy, dtype: float64
